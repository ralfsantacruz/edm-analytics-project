# %%
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine, inspect

# %%
# Create connection to database.
database = "music_data"
psql_engine = create_engine(f"postgresql://postgres:password@localhost/{database}")

# %%
df = pd.read_csv("top_100_hip_hop_.csv")

# %%
df.head()
# Out:
#    year                         artist                      song  \
# 0  2010                    Alicia Keys  Un-Thinkable (I'm Ready)
# 1  2010                          Usher        There Goes My Baby
# 2  2010                  Melanie Fiona               It Kills Me
# 3  2010                         Monica          Everything To Me
# 4  2010  Trey Songz Featuring Fabolous                   Say Aah
#
#                  track_id  rank  acousticness  \
# 0  4JOP8ELK6AaeySe7sKe996     1       0.73200
# 1  6IUiqtI8tE49sqGbmtrNd8     2       0.17500
# 2  6qU37BgVfPhpb2rhYzZWrF     3       0.21500
# 3  4ZOkuIDN8wRczzu1XUYC4y     4       0.47900
# 4  2fQ6sBFWaLv2Gxos4igHLy     5       0.00453
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/4JOP...         0.595
# 1  https://api.spotify.com/v1/audio-analysis/6IUi...         0.626
# 2  https://api.spotify.com/v1/audio-analysis/6qU3...         0.620
# ...

# %%
#  Check column types.
for col in df.columns:
    print(col, type(col[0]))
# Out:
# year <class 'str'>
# artist <class 'str'>
# song <class 'str'>
# track_id <class 'str'>
# rank <class 'str'>
# acousticness <class 'str'>
# analysis_url <class 'str'>
# danceability <class 'str'>
# duration_ms <class 'str'>
# energy <class 'str'>
# error <class 'str'>
# id <class 'str'>
# instrumentalness <class 'str'>
# key <class 'str'>
# liveness <class 'str'>
# loudness <class 'str'>
# mode <class 'str'>
# speechiness <class 'str'>
# tempo <class 'str'>
# time_signature <class 'str'>
# track_href <class 'str'>
# type <class 'str'>
# uri <class 'str'>
# valence <class 'str'>

# %%
# Pandas parses rank to int...
df[df['rank']>2]
# Out:
#      year                                         artist  \
# 2    2010                                  Melanie Fiona
# 3    2010                                         Monica
# 4    2010                  Trey Songz Featuring Fabolous
# 5    2010                                     Trey Songz
# 6    2010                          Usher Featuring Plies
# 7    2010                                  Mary J. Blige
# 8    2010      Chris Brown Featuring Tyga & Kevin McCall
# 9    2010                                   Robin Thicke
# 10   2010                                         Monica
# 11   2010                     Trey Songz Featuring Drake
# 12   2010                                       Ludacris
# 13   2010                      Timbaland Featuring Drake
# 14   2010                                          Drake
# 15   2010                                          Drake
# 16   2010                 Ludacris Featuring Nicki Minaj
# ...

# %%
# Let's see what happens if we push this to Postgres if all columns are str.
df.to_sql(name="hip_hop",index=False,con=psql_engine,if_exists='replace')

# %%
# Read in table.
query = "select * from hip_hop"
sql_table = pd.read_sql(query,psql_engine)

# %%
# Looks good...
sql_table.head()
# Out:
#    year                         artist                      song  \
# 0  2010                    Alicia Keys  Un-Thinkable (I'm Ready)
# 1  2010                          Usher        There Goes My Baby
# 2  2010                  Melanie Fiona               It Kills Me
# 3  2010                         Monica          Everything To Me
# 4  2010  Trey Songz Featuring Fabolous                   Say Aah
#
#                  track_id  rank  acousticness  \
# 0  4JOP8ELK6AaeySe7sKe996     1       0.73200
# 1  6IUiqtI8tE49sqGbmtrNd8     2       0.17500
# 2  6qU37BgVfPhpb2rhYzZWrF     3       0.21500
# 3  4ZOkuIDN8wRczzu1XUYC4y     4       0.47900
# 4  2fQ6sBFWaLv2Gxos4igHLy     5       0.00453
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/4JOP...         0.595
# 1  https://api.spotify.com/v1/audio-analysis/6IUi...         0.626
# 2  https://api.spotify.com/v1/audio-analysis/6qU3...         0.620
# ...

# %%
# Still strings when read into pandas.
for col in sql_table.columns:
    print(col, type(col[0]))
# Out:
# year <class 'str'>
# artist <class 'str'>
# song <class 'str'>
# track_id <class 'str'>
# rank <class 'str'>
# acousticness <class 'str'>
# analysis_url <class 'str'>
# danceability <class 'str'>
# duration_ms <class 'str'>
# energy <class 'str'>
# error <class 'str'>
# id <class 'str'>
# instrumentalness <class 'str'>
# key <class 'str'>
# liveness <class 'str'>
# loudness <class 'str'>
# mode <class 'str'>
# speechiness <class 'str'>
# tempo <class 'str'>
# time_signature <class 'str'>
# track_href <class 'str'>
# type <class 'str'>
# uri <class 'str'>
# valence <class 'str'>

# %%
# Inspect sql columns. Looks good! Postgres parsed them!
inspector = inspect(psql_engine)
inspector.get_columns('hip_hop')
# Out:
# [{'name': 'year',
#   'type': BIGINT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'artist',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'song',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'track_id',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'rank',
#   'type': BIGINT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'acousticness',
#   'type': DOUBLE_PRECISION(precision=53),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'analysis_url',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
# ...
