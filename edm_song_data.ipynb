# %%
import pandas as pd

# %%
edm = pd.read_csv('top_edm_songs.csv')
edm
# Out:
#      year                                             artist  \
# 0    2013                                             Baauer
# 1    2013              Daft Punk Featuring Pharrell Williams
# 2    2013                                             Avicii
# 3    2013                     Icona Pop Featuring Charli XCX
# 4    2013                               Zedd Featuring Foxes
# 5    2013                         will.i.am & Britney Spears
# 6    2013               Pitbull Featuring Christina Aguilera
# 7    2013                                          Lady Gaga
# 8    2013             Calvin Harris Featuring Ellie Goulding
# 9    2013          Swedish House Mafia Featuring John Martin
# 10   2013                      Lana Del Rey & Cedric Gervais
# 11   2013             Calvin Harris Featuring Florence Welch
# 12   2013                  will.i.am Featuring Justin Bieber
# 13   2013                                                PSY
# ...
